# %% [markdown]
# 04 Group comparison
#
# This notebook documents the planned group-level comparison.
#
# The goal of this step is to compare brain activation patterns between lower-grade and upper-grade children.

# %% [markdown]
# Group definition
#
# Participants will be divided into two developmental groups:
#
# Lower-grade group: Grades 1-3
# Upper-grade group: Grades 4-6
#
# The analysis will focus on developmental-stage-related differences in fNIRS responses.

# %% [markdown]
# Planned group-level contrast
#
# The main group-level contrast is:
#
# Upper-grade MA effect - Lower-grade MA effect
#
# This can be interpreted as the difference in MA-related brain activation between the two grade groups.

# %% [markdown]
# Expected group-level outputs
#
# The expected outputs include:
#
# group-level contrast tables
# significant channel tables
# corrected and uncorrected result summaries
# figures for the final report and presentation

# %%
from pathlib import Path

group_level_dir = Path("../results/group_level")
group_level_dir.mkdir(parents=True, exist_ok=True)

print(f"Group-level result directory: {group_level_dir}")

# %% [markdown]
# Notes for future implementation
#
# The group-level model will be implemented after the subject-level GLM outputs are available.
#
# The final implementation should clearly document model formula, grouping variables, contrast definitions, and correction methods.
