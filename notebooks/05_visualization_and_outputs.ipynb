# %% [markdown]
# 05 Visualization and outputs
#
# This notebook documents the planned visualization and output generation procedure.
#
# The goal of this step is to produce interpretable figures and tables for the final report, slides, and recorded presentation.

# %% [markdown]
# Visualization goals
#
# The visualization stage will summarize the main fNIRS analysis results.
#
# The expected visual outputs include:
#
# significant channel plots
# brain activation figures
# contrast summary figures
# tables for corrected and uncorrected results

# %% [markdown]
# Output folders
#
# The planned output folders are:
#
# figures/
# results/
# report/
# slides/
#
# Figures and non-sensitive summary tables may be uploaded to GitHub if they do not contain participant-identifiable information.

# %% [markdown]
# Figure style plan
#
# Figures should be clear and suitable for academic presentation.
#
# The current plan is to use simple and readable figures, with consistent scaling when comparing the same measurement across groups or contrasts.

# %%
from pathlib import Path

figures_dir = Path("../figures")
results_dir = Path("../results")

figures_dir.mkdir(parents=True, exist_ok=True)
results_dir.mkdir(parents=True, exist_ok=True)

print(f"Figures directory: {figures_dir}")
print(f"Results directory: {results_dir}")

# %% [markdown]
# Notes for future implementation
#
# The final visualization code should make it possible to regenerate figures from the analysis outputs.
#
# Manual figure editing should be minimized so that the workflow remains transparent and reproducible.
