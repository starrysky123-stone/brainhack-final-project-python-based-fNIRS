# %% [markdown]
# 03 First-level GLM
#
# This notebook documents the planned subject-level GLM procedure.
#
# The goal of this step is to estimate task-related brain activation for each participant.

# %% [markdown]
# GLM goal
#
# At the first level, the general linear model will be used to estimate task-related hemodynamic responses for each participant.
#
# The main task conditions include:
#
# MA
# PA
# Control
#
# The current project will prioritize MA-related contrasts.

# %% [markdown]
# Planned first-level contrasts
#
# The planned first-level analysis will estimate condition-related activation for each subject.
#
# The main contrast of interest is:
#
# MA - Control
#
# This contrast will later be compared between the lower-grade and upper-grade groups.

# %% [markdown]
# Expected first-level outputs
#
# The expected outputs include:
#
# subject-level beta estimates
# subject-level contrast estimates
# channel-wise GLM result tables
# local intermediate result files
#
# Large or sensitive result files should remain local and should not be uploaded to GitHub.

# %%
from pathlib import Path

first_level_dir = Path("../results/first_level")
first_level_dir.mkdir(parents=True, exist_ok=True)

print(f"First-level result directory: {first_level_dir}")

# %% [markdown]
# Notes for future implementation
#
# The implementation will refer to MNE-NIRS GLM examples if the local data can be represented in an MNE-compatible format.
#
# The final code should make the input files, model settings, and output files clear enough for reproducibility.
